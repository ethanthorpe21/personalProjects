# %%
import pandas as pd

# %%
matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  14.6  1.0  0     0
# 1  Leicester City  ...  Match Report    NaN  19.0  7.0  13.0  0.0  0     0
# 2     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.8  0.0  0     0
# 3          Fulham  ...  Match Report    NaN  22.0  8.0  15.5  1.0  0     0
# 4     Aston Villa  ...  Match Report    NaN  22.0  8.0  16.3  1.0  0     0
#
#   season     team
# 0   2023  Arsenal
# ...

# %%
matches.shape
# Out:
# (487, 27)

# %%
# Figure out how many matches per team
matches["team"].value_counts()
# Out:
# Arsenal                     28
# Tottenham Hotspur           28
# Everton                     28
# Wolverhampton Wanderers     28
# Crystal Palace              28
# Aston Villa                 27
# Leicester City              27
# Nottingham Forest           27
# Leeds United                27
# Chelsea                     27
# Manchester City             27
# Fulham                      27
# Brentford                   27
# Manchester United           27
# Brighton and Hove Albion    26
# Liverpool                   26
# Newcastle United            26
# West Ham United             26
# Name: team, dtype: int64

# %%
matches[matches["team"]=="Arsenal"]
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2   2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3   2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4   2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# 5   2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L  1.0
# 7   2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W  3.0
# 8   2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W  3.0
# 10  2022-10-09  16:30  Premier League  Matchweek 10  Sun  Home      W  3.0
# 12  2022-10-16  14:00  Premier League  Matchweek 11  Sun  Away      W  1.0
# 14  2022-10-23  14:00  Premier League  Matchweek 13  Sun  Away      D  1.0
# ...

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     18
# Matchweek 16    18
# Matchweek 27    18
# Matchweek 26    18
# Matchweek 24    18
# Matchweek 12    18
# Matchweek 23    18
# Matchweek 22    18
# Matchweek 21    18
# Matchweek 20    18
# Matchweek 19    18
# Matchweek 18    18
# Matchweek 2     18
# Matchweek 17    18
# Matchweek 15    18
# Matchweek 14    18
# Matchweek 13    18
# Matchweek 11    18
# Matchweek 10    18
# Matchweek 9     18
# Matchweek 6     18
# Matchweek 5     18
# Matchweek 4     18
# Matchweek 3     18
# Matchweek 8     16
# Matchweek 25    14
# Matchweek 28    14
# Matchweek 7     11
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
 # Change date to datetime  
 matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                   object
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
#Convert venue to numeric h/a 0 for away 1 for home
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
#Create code for each team
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
#Create code for match time
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
#Code for day of Match
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches

# %%
#Return 1 if W, 0 if D or L
matches["target"] = (matches["result"] == "W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-01-01']

# %%
test = matches[matches["date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
#create predictions off test data
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
#Getting accuracy score
acc
# Out:
# 0.6296296296296297

# %%
#Create DF with Predictions/Actuals
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           82  35
# 1           35  37

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.5138888888888888

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Arsenal")

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# 5  2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L  1.0
# 7  2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W  3.0
# 8  2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W  3.0
# 10 2022-10-09  16:30  Premier League  Matchweek 10  Sun  Home      W  3.0
# 12 2022-10-16  14:00  Premier League  Matchweek 11  Sun  Away      W  1.0
# 14 2022-10-23  14:00  Premier League  Matchweek 13  Sun  Away      D  1.0
# 16 2022-10-30  14:00  Premier League  Matchweek 14  Sun  Home      W  5.0
# ...

# %%
#Create Rolling Averages Method
#Cut off at week 3, does not include current week only past data
def rolling_averages(group, cols, new_cols):
  group = group.sort_values("date")
  rolling_stats = group[cols].rolling(3, closed='left').mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset=new_cols)
  return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 3  2022-08-27  17:30  Premier League   Matchweek 4
#                         4  2022-08-31  19:30  Premier League   Matchweek 5
#                         5  2022-09-04  16:30  Premier League   Matchweek 6
#                         7  2022-09-18  12:00  Premier League   Matchweek 8
#                         8  2022-10-01  12:30  Premier League   Matchweek 9
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 29 2023-02-24  20:00  Premier League  Matchweek 25
#                         30 2023-03-01  20:00  Premier League   Matchweek 7
#                         31 2023-03-04  15:00  Premier League  Matchweek 26
#                         32 2023-03-12  16:30  Premier League  Matchweek 27
#                         33 2023-03-18  15:00  Premier League  Matchweek 28
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# 5  2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L  1.0
# 7  2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W  3.0
# 8  2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 29 2023-02-24  20:00  Premier League  Matchweek 25  Fri  Away      D  1.0
# 30 2023-03-01  20:00  Premier League   Matchweek 7  Wed  Away      L  0.0
# 31 2023-03-04  15:00  Premier League  Matchweek 26  Sat  Home      W  1.0
# 32 2023-03-12  16:30  Premier League  Matchweek 27  Sun  Away      L  1.0
# 33 2023-03-18  15:00  Premier League  Matchweek 28  Sat  Home      L  2.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.5116279069767442

# %%
combined
# Out:
#     actual  predicted       date                      team        opponent  \
# 18       0          0 2022-11-06                   Arsenal         Chelsea
# 18       0          0 2023-01-01               Aston Villa       Tottenham
# 18       0          0 2022-12-30                 Brentford        West Ham
# 18       0          0 2022-12-31  Brighton and Hove Albion         Arsenal
# 18       0          0 2022-11-06                   Chelsea         Arsenal
# ..     ...        ...        ...                       ...             ...
# 39       0          0 2023-03-18         Tottenham Hotspur     Southampton
# 40       1          0 2023-03-11           Manchester City  Crystal Palace
# 41       0          0 2023-03-05         Manchester United       Liverpool
# 43       0          1 2023-03-12         Manchester United     Southampton
# 45       0          1 2023-03-19         Manchester United        Brighton
#
#    result         new_team
# 18      W          Arsenal
# ...

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted     date_x   team_x opponent_x result_x new_team  \
# 18       0          0 2022-11-06  Arsenal    Chelsea        W  Arsenal
# 18       0          0 2022-11-06  Arsenal    Chelsea        W  Arsenal
# 18       0          0 2022-11-06  Arsenal    Chelsea        W  Arsenal
# 18       0          0 2022-11-06  Arsenal    Chelsea        W  Arsenal
# 18       0          0 2022-11-06  Arsenal    Chelsea        W  Arsenal
# 18       0          0 2022-11-06  Arsenal    Chelsea        W  Arsenal
# 18       0          0 2022-11-06  Arsenal    Chelsea        W  Arsenal
# 18       0          0 2022-11-06  Arsenal    Chelsea        W  Arsenal
# 18       0          0 2022-11-06  Arsenal    Chelsea        W  Arsenal
# 18       0          0 2022-11-06  Arsenal    Chelsea        W  Arsenal
#
#        date_y                    team_y       opponent_y result_y
# 18 2022-11-06                   Arsenal          Chelsea        W
# ...

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#        actual_x  predicted_x       date             team_x opponent_x  \
# 0             0            0 2022-11-06            Arsenal    Chelsea
# 1             0            0 2022-11-06            Arsenal    Chelsea
# 2             0            0 2022-11-06            Arsenal    Chelsea
# 3             1            1 2022-11-06            Arsenal    Chelsea
# 4             1            1 2022-11-06            Arsenal    Chelsea
# ...         ...          ...        ...                ...        ...
# 18109         0            1 2023-03-19  Manchester United   Brighton
# 18110         0            1 2023-03-19  Manchester United   Brighton
# 18111         0            1 2023-03-19  Manchester United   Brighton
# 18112         0            1 2023-03-19  Manchester United   Brighton
# 18113         0            1 2023-03-19  Manchester United   Brighton
#
#       result_x      new_team_x  actual_y  predicted_y  \
# 0            W         Arsenal         0            0
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 0    1581
# 1    1445
# Name: actual_x, dtype: int64

# %%
1445/3026
# Out:
# 0.47752808988764045
